# %%
from main import *

# %%
df.head()
# Out:
#                                                   nombre_producto  \
# id_producto
# 2792-88-LE21-1  Equipo quirúrgico de fragmatome retinal vítreo...
# 1704-52-LP21-1            Servicios de transporte local en camión
# 1003-20-L121-1                    Desperdicios o restos de madera
# 4236-21-L121-1                                         Marcadores
# 4236-21-L121-2                                           Péndulos
#
#                                                       descripcion  label  \
# id_producto
# 2792-88-LE21-1  CÁMARA RETINAL NO MIDRIÁTICA - ESPECIFICACIONE...      0
# 1704-52-LP21-1  SERVICIO DE MUDANZA DE ENSERES PROPIOS Y EN US...      0
# 1003-20-L121-1                              LEÑA SECA CERTIFICADA      0
# 4236-21-L121-1                       MARCADOR BLANCO PARA METALES      0
# 4236-21-L121-2                                            PLOMADA      0
#
#                 Rubro1_Artículos de electrónica  \
# id_producto
# ...

# %%
matriz_palabras
# Out:
# <51795x32544 sparse matrix of type '<class 'numpy.float64'>'
# 	with 449992 stored elements in Compressed Sparse Row format>

# %%
len(vectorizador.vocabulary_)
# Out:
# 32544
